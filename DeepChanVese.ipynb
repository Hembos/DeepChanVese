# %% [markdown]
# # Умный Chan Vese для сегментации изображений

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ## Алгоритм сегментации

# %%
import tensorflow as tf
from keras.layers import Conv2D, BatchNormalization, Activation, ZeroPadding2D, MaxPooling2D, Add, Input
from keras import Model

import numpy as np
# from resFpn import ResFPN

# %%
IMG_WIDTH = 352
IMG_HEIGHT = 260
IMG_CHANNELS = 3

seed = 42
np.random.seed = seed

EPOCHS_NUM = 100
BATCH_SIZE = 16
TRAIN_PATH = 'train/'
TEST_PATH = 'test/'

# %% [markdown]
# ### Resnet50 + FPN

# %%
resFPN = ResFPN((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
resFPN.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 260, 352, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 266, 358, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 130, 176, 64  9408        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 130, 176, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 130, 176, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 132, 178, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 65, 88, 64)   0           ['pool1_pad[0][0]']
#
# ...
